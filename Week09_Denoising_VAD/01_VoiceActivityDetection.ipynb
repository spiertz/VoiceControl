# %% [markdown]
# # Voice activity detection
# The signalflow of the discussed keyword spotter so far is as follows:
# - The audio analysis starts with the audio recording by a microphone, as discussed in the Jupyter Notebook [Preprocessing, ADC](../Week02_Preprocessing_ADC/01_InputSignals.ipynb). In this Notebook, the basic principles of analogue-digital conversion as sampling and quantization are explained together with their limitations regarding audio recordings. Basic acoustic logarithmic measures like level in dB SPL or dB FS are introduced. It is shown, that dithering is a simple yet effective noise shaping algorithm for quantisation tasks. If a low-power edge device is assumed, computationel complexity is always an issue. Therefore, downsampling is introduced as a simple data reduction scheme.
# - After the recording, the audio signal is transformed into a spectrogram, e.g. by the Short time Fourier transform, as discussed in the Jupyter Notebook [STFT](../Week04_Preprocessing_STFT/01_ShortTimeFourierTransform.ipynb). The spectrogram is an image-like representation of the audio signal, which shows simultaneously signal properties over the time axis and over the frequencie axis. The transformation into a spectrogram is a necessary condition for applying the Wiener filter as introduced in the denoising stage. Additionally, the spectrogram with its two-dimensional size allows us to utilize all image classification networks, as introduced later in the machine learning stage.
# - Every recording is noisy by definition: there is no noise free recording available. If the noise is getting to aggressive, the keyword spotter may fail, due to misinterpration of the recorded signal. Therefore, classical denoising algorithms are proposed in the following. The focus is laid on simple algorithms, which can be applied on low-power edge devices. Additionally, the focus is laid on algorithms, which are not only restricted to audio analysis. In Denoising part 1 of 3, the swiss army knife of denoising is introduced: the bandpass, as discussed in the Jupyter Notebook [Bandpass](../Week05_Denoising_Bandpass/01_DiscreteFiltering.ipynb). The bandpass is the simplest possible denoising algorithm to get rid of noise, which is non overlapping with the wanted signal in spectral domain.
# - For frequencies with both noise and wanted signal, the bandpass is no option for denoising. The next simplest and robust denoising algorithm is introduced in Denoising part 2 of 3: the Wiener Filter and its variations like spectral subtraction, as discussed in the Jupyter Notebook [Wiener Filter](../Week06_Denoising_WienerFilter/01_DenoiserWienerFilter.ipynb).
# - If more than one sensor-signals are available, the recorded signals can be combined in order to reduce the background noise. In [Delay and sum beamformer](../Week08_Denoising_Beamforming/01_DelayAndSumBeamformer.ipynb), a simple algorithm for combining several sensor signals is introduced. The underlying channel model is, that the path from the single source to microphone $i$ is described by delay $T_i$ and damping $a_i$, thus forming the impulse response for this channel $h_in()=a\cdot\delta\left(n-T_i\right)$. Under this model assumption, the delay and sum beamformer increases the [SNR](../Basics/SignalToNoiseRatio.ipynb) with every additional microphone.
# - In the following, Denoising part 4 of 4 is introduced: Voice activity detection (VAD) algorithms decides whether a single block of audio contains human voice or not. Where the [Bandpass](../Week05_Denoising_Bandpass/01_DiscreteFiltering.ipynb) decides for the frequency axis, whether voice is active or not, VAD algorithms decides over the time axis, whether voice is active or not.

# %% [markdown]
# ## Introduction
# Voice activity detection (VAD) are algorithms which decide for a single temoral block of audio, if it is background noise or human speech. VAD algorithms are typically very fast and simple to implement. Therefore, the VAD can run continuously on an input stream from a microphone. Only in the case of active human voice, the classification, transcription, and further algorithms are performed, which are usually much more complex algorithms. By this two step decision process with
#
# - simple and lightweight VAD
# - followed by more sophisticated voice analysis only for active voice segments,
#
# the overall computational complexity is reduced a lot and a lot of energy consumption of the CPU is saved.
#
# Run all code blocks of this Notebook. A list of wave files are created in the working folder:
#
# - 'Original.wav' is the noisy recording.
# - 'VAD_WordNumer_XYZ.wav' is the detected word with index XYZ.
#
# Play around with the parameter NoiseGain in the range $0.01 .. 0.5$ and listen the generated wave files in order to understand the influence of the amount of noise to the proposed simple VAD algorithm.

# %%
NoiseGain = 0.01

import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.insert(1, '../Basics')
import WaveFileHandling

# delete all wave files in the current directory for allowing repeated runs of this notebook without manual cleanup
import os
for file in os.listdir('.'):
    if file.endswith('.wav'):
        os.remove(file)

x, Fs = WaveFileHandling.ReadWaveAsNumpyArray('../Audio/PferdeSchnaubenNichtDieNase.wav')
y = x + NoiseGain * np.random.randn(x.shape[0])
SNR = 10*np.log10(np.sum(x**2) / np.sum((x-y)**2))
print('Assuming a recording situation with ', SNR, ' dB of SNR.')

t = np.arange(y.shape[0]) / Fs
plt.plot(t, y)
plt.xlabel('t (s)')
plt.ylabel('(noisy) waveform')
plt.show()

WaveFileHandling.WriteWaveAsNumpyArray(y, Fs, 'Original.wav')
# Out:
# Assuming a recording situation with  19.22018133785621  dB of SNR.

# %% [markdown]
# ## VAD feature: level
# In a typical recording situation the human voice is louder than the background noise. Otherwise, the voice would be hard to recognize, even for human listeners.
#
# In the following a blocksize of $10$ ms is chosen for analysing the recording. $10$ ms is a reasonable block size for analysing human speech. Additionally, the WebRTCVad algorithm introduced later in this Notebook works with block sizes of $10$ ms.
#
# Therefore, the level in dB FS of a block of audio is a reasonable feature for detecting human voice:

# %%
def EvaluateLevel(x):
    A = 1 # maximum magnitude of a wave file
    P = np.mean(x**2)
    L = 10*np.log10(2*P/(A**2))
    return L
    
BlocksizeInMs = 10
BlocksizeInSamples = int(BlocksizeInMs * Fs / 1000)
NumberOfBlocks = y.shape[0] // BlocksizeInSamples
L = np.zeros((NumberOfBlocks))
for n in range(NumberOfBlocks):
    idx1 = n * BlocksizeInSamples
    idx2 = idx1 + BlocksizeInSamples
    L[n] = EvaluateLevel(y[idx1:idx2])

fig = plt.figure(1)
ax = fig.add_subplot(111)
t = np.arange(y.shape[0]) / Fs
ax.plot(t, y, 'b')
ax.set_ylabel('y(t)')
ax2 = ax.twinx()
t = (np.arange(L.shape[0]) + 0.5) * BlocksizeInMs / 1000
ax2.plot(t, L, 'r')
ax2.set_ylabel('L [dB FS]')
ax.set_xlabel('t (s)')
plt.show()

# %% [markdown]
# ## Threshold
# Audio feature are usually measured in a continous way. E.g. the level in dB FS is usually in the range from $-100$ dB Fs up to $0$ dB FS. In order to decide, which block is voice and which block is background noise, a threshold must be defined.
#
# The histogram of the measured level values shows two peaks in the distribution of the level values:
#
# The higher peak on the right corresponds to voice: The higher the level, the higher the probability of active voice.
# The lower peak on the left corresponds to background noise: The lower the level, the higher the probability of background noise without voice.

# %%
plt.hist(L)
plt.xlabel('L [dB FS]')
plt.show()

# %% [markdown]
# ## Clustering by k-means
# In order to transform the soft decision criteria of level in dB FS into a hard decision criteria 'voice is active' or 'voice is not active', a threshold is needed. All levels above this threshold are assumed to be voice. All levels below the threshold are assumed to be background noise. A simple algorithm to detect two centroids in a list of values is the k-means algorithm, which is shown in the following.
#
# a) The centers $c_1$ and $c_2$ are initialized at the maximum and the minimum level. The center $c_2$ corresponds to a speech sample (because it correspongs to the maximum observed level).
#
# b) Evaluate for all blocks the distances to the centers $c_1$ and $c_2$. The block is classified as speech if the distance to $c_2$ is smaller than the distance to $c_1$.
#
# c) Update the centers as the mean values of all samples of $L$ which are allocated to their group: $c_1$ is the mean value of all non-voice blocks, $c_2$ is the mean value of all voice blocks.
#
# d) start again with step b) until a certain amount of iterations are done.

# %%
def EvalIsSpeech(L, c1, c2):
    IsSpeech = np.zeros(L.shape[0], dtype = bool)
    for sample in range(L.shape[0]):
        d1 = np.sum((L[sample] - c1)**2)
        d2 = np.sum((L[sample] - c2)**2)
        if d2 < d1:
            IsSpeech[sample] = True
        else:
            IsSpeech[sample] = False
    return IsSpeech

def UpdateCenters(L, IsSpeech):
    c1 = np.mean(L[~IsSpeech])
    c2 = np.mean(L[IsSpeech])
    return c1, c2

def KMeansSingleFeature(L):
    c1 = np.min(L)
    c2 = np.max(L)
    IsSpeech = EvalIsSpeech(L, c1, c2)
    for iter in range(5):        
        c1, c2 = UpdateCenters(L, IsSpeech)
        IsSpeech = EvalIsSpeech(L, c1, c2)
    print('mean level of background noise = ', c1, ' dB FS')
    print('mean level of speech = ', c2, ' dB FS')
    return IsSpeech

IsSpeech = KMeansSingleFeature(L)
# Out:
# mean level of background noise =  -35.37022477152458  dB FS
# mean level of speech =  -15.486417239691518  dB FS

# %% [markdown]
# With the k-means algorithm a simple, yet reasonable threshold can be estimated. With this threshold a binary decision 'voice is active' or 'voice is not active' can be done:

# %%
t = np.arange(y.shape[0]) / Fs
plt.plot(t, y, 'b', label='waveform')
t = (np.arange(IsSpeech.shape[0]) + 0.5) * BlocksizeInMs / 1000
plt.plot(t, IsSpeech, 'r', label='IsSpeech')
plt.xlabel('t [s]')
plt.legend()
plt.show()

# %% [markdown]
# ## Blockwise analysis
# The block wise binary decision of 'active voice' vs. 'non-active voice' is transformed into beginning and ending of single words in the following:
#
# If the former block is not speech and the current block is speech, the beginning of a word is assumed.
# If the former block is speech and the current block is not speech, the ending of a word is assumed.
# The variable "IsTriggered" corresponds to the information: the algorithm assumes currently active voice.

# %%
IndexOfWord = 0
IsTriggered = False
for n in range(1, IsSpeech.shape[0]):
    CurrentSamplingPosition = int(n * BlocksizeInMs / 1000 * Fs)
    if (not IsSpeech[n-1]) and (IsSpeech[n]) and (not IsTriggered):
        IsTriggered = True
        BeginningOfWordInSamples = CurrentSamplingPosition
    if (IsSpeech[n-1]) and (not IsSpeech[n]) and (IsTriggered):
        IsTriggered = False
        EndingOfWordInSamples = CurrentSamplingPosition
        FileName = 'VAD_WordNumber_' + str(IndexOfWord) + '.wav'
        IndexOfWord += 1
        WordSamples = y[BeginningOfWordInSamples:EndingOfWordInSamples]
        WaveFileHandling.WriteWaveAsNumpyArray(WordSamples, Fs, FileName)
print(IndexOfWord, ' words detected')
# Out:
# 6  words detected

# %% [markdown]
# ## WebRTCVad
# Evaluating the level in dB FS results in a very simple feature for VAD. This simple detector has problems, if the k-means algorithm estimates a wrong threshold for this single feature.
# The typical approach for improving the robustness of the algorithm is to increase the number of features and combine these features in a smarter way compared to the k-means algorithm in order to get a more robust voice detector.
#
# The package WebRTCVad has optimised this approach: WebRTCVad is a lightweight, robust and free tool for detecting active voice in a temporal segment recorded by a microphone. The corresponding python-wrapper is published under MIT license. Sample code for utilizing the WebRTCVad is shown in the following:

# %%
# source:
# https://pypi.org/project/webrtcvad/

import webrtcvad
import librosa

class CWebRTCVadWrapper(object):

    def __init__(self, Aggressiveness = 2):
        self.__vad = webrtcvad.Vad()
        self.__vad.set_mode(Aggressiveness)

    def IsSpeech(self, NumpyArray, SampleRate):
        if not (SampleRate in [8000, 16000, 32000]):
            TargetSamplingRate = 16000
            NumpyArray = librosa.resample(NumpyArray, orig_sr = SampleRate, target_sr = TargetSamplingRate)
            SampleRate = TargetSamplingRate
        # source:
        # https://stackoverflow.com/questions/51486093/convert-pcm-wave-data-to-numpy-arrays-and-vice-versa
        ints = (NumpyArray * ((2**16) - 1)).astype(np.int16)
        little_endian = ints.astype('<u2')
        buf = little_endian.tobytes()
        return self.__vad.is_speech(buf, SampleRate)

AWebRTCVadWrapper = CWebRTCVadWrapper()
WebRTCVadOutput = np.zeros((NumberOfBlocks))
for n in range(NumberOfBlocks):
    idx1 = n * BlocksizeInSamples
    idx2 = idx1 + BlocksizeInSamples
    WebRTCVadOutput[n] = AWebRTCVadWrapper.IsSpeech(y[idx1:idx2], Fs)

t = np.arange(y.shape[0]) / Fs
plt.plot(t, y, 'b', label='waveform')
t = (np.arange(IsSpeech.shape[0]) + 0.5) * BlocksizeInMs / 1000
plt.plot(t, IsSpeech, 'r', label='Energy-based VAD')
plt.plot(t, WebRTCVadOutput, 'k', label='WebRTC VAD')
plt.xlabel('t [s]')
plt.legend()
plt.show()

# %% [markdown]
# ## Programming exercise
# The level in dB FS is heavily depending on the SNR of the recording. The above suggested algorithm will fail if the SNR falls below a certain value.
#
# The zero crossing rate is an audio feature independent from the level of the speech signal and the level of the background noise. The zero crossing rate is defined by:
#
# $\text{zcr} = \frac{1}{N-1}\sum_{n=1}^{N-1} \varepsilon\left(-x(n)\cdot x(n-1)\right)$
#
# with the unit step $\varepsilon\left(x\right)$ defined as follows:
#
# $\varepsilon(x) = \begin{cases}
#         1 & \text{if } x \geq 0\\
#         0 & \text{else}
#     \end{cases}$
#
# A small value of zcr corresponds to speech, a large value corresponds to noise.
#
# Implement the procedure Unitstep and the procedure EvaluateZCR.
#
# Implement the procedure TransformToUniformDistribution, which restricts the columns of the input matrix to a range of $0..1$ without changing the order of the elements.
#
# Additionally, implement the procedures EvalIsSpeech and UpdateCenters for a k-means algorithm under the assumption, that several features are used for clustering. The input argument Features corresponds to a N by M matrix, with N blocks in the analysed signal and M is the number of the different features (the dimension of the feature space).

# %%
def Unitstep(x):
    result = 0.0
    ### solution
    result = (x >= 0) + 0.0
    ### solution
    return result

def EvaluateZCR(x):
    zcr = 0.0
    ### solution
    zcr = np.mean(Unitstep(-x[1:]*x[:-1]))
    ### solution
    return zcr

def TransformToUniformDistribution(Features):
    # solution
    for FeatureIndex in range(Features.shape[1]):
        tmp = Features[:, FeatureIndex]
        Minimum = np.min(tmp)
        Maximum = np.max(tmp)
        UniformValues = (tmp - Minimum) / (Maximum - Minimum)
        Features[:, FeatureIndex] = UniformValues
    # solution
    return Features

def EvalIsSpeech(Features, c1, c2):
    IsSpeech = np.zeros((Features.shape[0]), dtype=bool)
    # solution
    for sample in range(Features.shape[0]):
        d1 = np.sum((Features[sample, :] - c1)**2)
        d2 = np.sum((Features[sample, :] - c2)**2)
        IsSpeech[sample] = d2 < d1
    # solution
    return IsSpeech

def UpdateCenters(Features, IsSpeech):
    # solution
    c1 = np.mean(Features[~IsSpeech, :], axis=0)
    c2 = np.mean(Features[ IsSpeech, :], axis=0)
    # solution
    return c1, c2

def KMeansMultipleFeatures(Features):
    # for all features: a uniform distribution in the range 0..1 is assumed
    assert np.all(Features >= 0) and np.all(Features <= 1), 'All features must be in the range 0..1'
    # for all features: the higher the value, the more likely it is speech
    FeatureSum = np.sum(Features, axis=1)
    Index1 = np.argmin(FeatureSum) # center of non-voice
    Index2 = np.argmax(FeatureSum) # center of voice
    c1 = Features[Index1, :]
    c2 = Features[Index2, :]
    IsSpeech = EvalIsSpeech(Features, c1, c2)
    for iter in range(5):        
        c1, c2 = UpdateCenters(Features, IsSpeech)
        IsSpeech = EvalIsSpeech(Features, c1, c2)
    return IsSpeech

Features = np.zeros((NumberOfBlocks, 2))
Features[:, 0] = L
for n in range(NumberOfBlocks):
    idx1 = n * BlocksizeInSamples
    idx2 = idx1 + BlocksizeInSamples
    Features[n, 1] = -EvaluateZCR(y[idx1:idx2]) # the higher the ZCR, the more likely it is non-voice, therefore the negative value is used as feature
Features = TransformToUniformDistribution(Features)
IsSpeech = KMeansMultipleFeatures(Features)
t = np.arange(y.shape[0]) / Fs
plt.plot(t, y, 'b', label='waveform')
t = (np.arange(IsSpeech.shape[0]) + 0.5) * BlocksizeInMs / 1000
plt.plot(t, IsSpeech, 'r')
plt.xlabel('t [s]')
plt.title('VAD based on multiple features')
plt.show()

import unittest

class TestProgrammingExercise(unittest.TestCase):

    def test_ZCR(self):
        r = 48000
        f = np.random.rand(1) * r / 2
        t = np.arange(r)/r
        x = np.cos(2*np.pi*f*t)
        ZCR = EvaluateZCR(x)
        self.assertAlmostEqual(ZCR*r, 2*f, delta = 10)
        
    def test_UnitstepScalar(self):
        x = np.random.randn(1)**2     
        self.assertAlmostEqual(Unitstep(x), 1.0, delta = 1e-15)
        x *= -1
        x -= 1e-15
        self.assertAlmostEqual(Unitstep(x), 0.0, delta = 1e-15)

    def test_UnitstepVector(self):
        x = np.arange(3) - 1
        self.assertAlmostEqual(Unitstep(x[0]), 0.0, delta = 1e-15)
        self.assertAlmostEqual(Unitstep(x[1]), 1.0, delta = 1e-15)
        self.assertAlmostEqual(Unitstep(x[2]), 1.0, delta = 1e-15)

    def test_MonotonicityOfTransformToUniformDistribution(self):
        x = np.random.randn(1000)
        IdxIn = np.argsort(x)
        y = TransformToUniformDistribution(x.reshape(-1, 1)).flatten()
        IdxOut = np.argsort(y)
        self.assertTrue(np.all(IdxIn == IdxOut))

    def test_RangeOfTransformToUniformDistribution(self):
        x = np.random.randn(1000)
        y = TransformToUniformDistribution(x.reshape(-1, 1)).flatten()
        self.assertGreaterEqual(np.min(y), 0.0)
        self.assertLessEqual(np.max(y), 1.0)

    def test_EvalIsSpeech1(self):
        Features = np.random.randn(5, 3)
        RandomVoiceIndex = np.random.randint(Features.shape[0])
        RandomNoiseIndex = (RandomVoiceIndex + 1) % Features.shape[0]
        c1 = Features[RandomNoiseIndex, :]
        c2 = Features[RandomVoiceIndex, :]
        IsSpeech = EvalIsSpeech(Features, c1, c2)
        self.assertFalse(IsSpeech[RandomNoiseIndex])
        self.assertTrue(IsSpeech[RandomVoiceIndex])

    def test_EvalIsSpeech2(self):
        c1 = np.random.randn(1,5)
        c2 = np.random.randn(1, c1.shape[1])
        Features = np.random.randn(100, c1.shape[1])
        IsSpeechGroundTruth = np.zeros((Features.shape[0]), dtype=bool)
        for SampleIndex in range(Features.shape[0]):
            a = np.random.rand(1)
            Features[SampleIndex, :] = c1 + (c2 - c1) * a
            IsSpeechGroundTruth[SampleIndex] = a > 0.5
        IsSpeech = EvalIsSpeech(Features, c1, c2)
        self.assertTrue(np.all(IsSpeech == IsSpeechGroundTruth))

    def test_UpdateCenters(self):
        m = np.random.rand(1) * 10
        s = np.random.rand(1) * 5
        Features = np.random.randn(1000, 4) * s + m
        # initialise with all false, i.e., all samples are assigned to the non-voice class
        IsSpeech = np.zeros((Features.shape[0]), dtype=bool)
        RandomTrueIndex = np.random.randint(Features.shape[0])
        IsSpeech[RandomTrueIndex] = True
        c1, c2 = UpdateCenters(Features, IsSpeech)
        self.assertTrue(np.all(c2 == Features[RandomTrueIndex, :]))
        self.assertAlmostEqual(np.sum(np.abs(c1 - m)), 0.0, delta = 1e-0)
        

unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_EvalIsSpeech1 (__main__.TestProgrammingExercise.test_EvalIsSpeech1) ... ok
# test_EvalIsSpeech2 (__main__.TestProgrammingExercise.test_EvalIsSpeech2) ... ok
# test_MonotonicityOfTransformToUniformDistribution (__main__.TestProgrammingExercise.test_MonotonicityOfTransformToUniformDistribution) ... ok
# test_RangeOfTransformToUniformDistribution (__main__.TestProgrammingExercise.test_RangeOfTransformToUniformDistribution) ... ok
# test_UnitstepScalar (__main__.TestProgrammingExercise.test_UnitstepScalar) ... ok
# test_UnitstepVector (__main__.TestProgrammingExercise.test_UnitstepVector) ... ok
# test_UpdateCenters (__main__.TestProgrammingExercise.test_UpdateCenters) ... ok
# test_ZCR (__main__.TestProgrammingExercise.test_ZCR) ... ok
#
# ----------------------------------------------------------------------
# Ran 8 tests in 0.023s
#
# OK

# %% [markdown]
# ## Exam preparation
# 1) Evaluate the zero crossing rate of a sinus with a frequency of $1234$ Hz.
#
# 2) Assuming a feature space with $N=4$ samples and $M=2$ dimensions. The features are $f_0=[0, 0]$, $f_1=[0, 2]$, $f_2=[3,0]$ and $f_3=[1,2]$. The centers are initialized with $c_1=[0,0]$ and $c_2=[2,2]$. Simulate one iteration of the k-means algorithm by first evaluating the distances to the given centers and second updating the centers as mean values of the samples, which are closer to them than to other centers. Use the squared Euclidean distance for evaluating the distance to the centers.
#
# 3) Plot the unit step function $\varepsilon(x)$ for $-2<x<2$. Is the unit step a linear function? Hint: For a linear function $f(x)$ the following must be true: $f(a\cdot x_1+b\cdot x_2) = a\cdot f\left(x_1\right)+b\cdot f\left(x_2\right)$.
#
# 4) Why are the timestamps of the blockwise features evaluated by the following equation: **t = (np.arange(IsSpeech.shape[0]) + 0.5) * BlocksizeInMs / 1000**. Explain especially the addition of the term $+0.5$.
#
# 5) What is the highest and the lowest possible zero crossing rate according to the above given algorithm? (hint: assuming big numbers of $N$)

# %% [markdown]
# ## Summary
# After working with this Jupyter Notebook you should be able to explain the following topics:
#
# - Name two features for VAD.
# - Is high or low ZCR related to speech?
# - Is high or low level related to speech?
